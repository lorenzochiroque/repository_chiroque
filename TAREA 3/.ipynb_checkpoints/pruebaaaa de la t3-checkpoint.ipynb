# %%
import pandas as pd

# %%
modulo1 = pd.read_csv('Enaho01-2020-100.csv')

# %%
modulo341 = pd.read_csv('Sumaria-2020.csv')

# %% [markdown]
# 2. - ¿Cuáles son las dimensiones de la sumaria? (o el número de filas y columnas).
#    - ¿Cuáles son las dimensiones del módulo de vivienda? (o el número de filas y columnas).

# %%
modulo1.shape
# Out:
# (53423, 331)

# %%
modulo341.shape
# Out:
# (34490, 179)

# %%
modulo341
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...       LINEA  POBREZA  TIPOCUESTIONARIO  \
# 0             2         2  ...  303.520996        3                 0
# 1             2         2  ...  303.520996        3                 0
# 2             6         6  ...  303.520996        3                 0
# 3             4         4  ...  303.520996        3                 0
# 4             4         4  ...  303.520996        3                 0
# ...         ...       ...  ...         ...      ...               ...
# 34485         1         1  ...  335.352234        3                 2
# 34486         1         1  ...  335.352234        3                 2
# 34487         1         1  ...  335.352234        3                 2
# 34488         4         4  ...  335.352234        3                 2
# 34489         4         4  ...  335.352234        3                 2
#
#        TIPOENTREVISTA    FACTOR07  NCONGLOME  SUB_CONGLOME  LINEAV_RPL  \
# 0                   1  149.202744       7076             0         657
# 1                   1  149.202744       7076             0         657
# 2                   1  149.202744       7076             0         657
# 3                   1   70.492592       7089             0         657
# 4                   1   70.492592       7089             0         657
# ...               ...         ...        ...           ...         ...
# 34485               1  275.828552      15122             0         657
# 34486               1  275.828552      15122             0         657
# 34487               1  275.828552      15122             0         657
# 34488               1  275.828552      15122             0         657
# 34489               1  275.828552      15122             0         657
#
#            LINEAV  POBREZAV
# 0      560.468506         4
# 1      553.731506         4
# 2      547.194031         3
# 3      556.025330         4
# 4      548.526917         4
# ...           ...       ...
# 34485  641.312134         4
# 34486  642.814026         4
# 34487  641.782898         4
# 34488  643.160034         3
# 34489  639.233521         3
#
# [34490 rows x 179 columns]

# %% [markdown]
# 3. En esta oportunidad no necesitaremos todas las variables de la ENAHO para hacer esta tarea.
# - Quedémonos con las variables ``` CONGLOME VIVIENDA HOGAR MIEPERHO PERCEPHO POBREZA GASHOG2D INGHOG2D ``` de la sumaria.
# - Quedémonos con las variables ``` CONGLOME VIVIENDA HOGAR RESULT NBI1 NBI2 NBI3 NBI4 NBI5 ``` del módulo de vivienda.
#
#
#  Nota: cada una de las variables es:
# - MIEPERHO: número de miembros del hogar.
# - PERCEPHO: número de perceptores del hogar (que reciben un ingreso).
# - POBREZA: Pobreza monetaria según la línea de pobreza.
# - GASHOG2D: Gasto bruto anual del hogar.
# - INGHOG2D: Ingreso anual neto total del hogar.
#
# Necesidades básicas:
# - NBI1: vivienda inadecuada.
# - NBI2: hacinamiento
# - NBI3: vivienda sin servicios higiénicos
# - NBI4: hogares con  niños que no asisten a la escuela.
# - NBI5: hogares con alta dependencia económica
#
# CONGLOME, VIVIENDA y HOGAR son los identificadores únicos a nivel de hogar (como un key id).

# %%
needed1 = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'RESULT', 'NBI1', 'NBI2', 'NBI4', 'NBI5']

# %%
needed341 = ['CONGLOME', 'VIVIENDA', 'MIEPERHO', 'PERCEPHO', 'POBREZA', 'GASHOG2D', 'INGHOG2D']

# %%
modulo1[needed1]
# Out:
#        CONGLOME  VIVIENDA  HOGAR  RESULT NBI1 NBI2 NBI4 NBI5
# 0          5009        12     11       1    0    0    0    0
# 1          5009        41     11       1    0    0    0    0
# 2          5009        56     11       7
# 3          5009        84     11       7
# 4          5009        98     11       1    0    0    0    0
# ...         ...       ...    ...     ...  ...  ...  ...  ...
# 53418     20305        52     11       1    0    0    0    0
# 53419     20305        73     11       1    1    0    0    0
# 53420     20305        94     11       7
# 53421     20305       116     11       1    0    0    0    0
# 53422     20305       137     11       1    0    0    0    0
#
# [53423 rows x 8 columns]

# %%
modulo341_small = modulo341[needed341]

# %%
modulo1_small = modulo1[needed1]

# %%
modulo1_small
# Out:
#        CONGLOME  VIVIENDA  HOGAR  RESULT NBI1 NBI2 NBI4 NBI5
# 0          5009        12     11       1    0    0    0    0
# 1          5009        41     11       1    0    0    0    0
# 2          5009        56     11       7
# 3          5009        84     11       7
# 4          5009        98     11       1    0    0    0    0
# ...         ...       ...    ...     ...  ...  ...  ...  ...
# 53418     20305        52     11       1    0    0    0    0
# 53419     20305        73     11       1    1    0    0    0
# 53420     20305        94     11       7
# 53421     20305       116     11       1    0    0    0    0
# 53422     20305       137     11       1    0    0    0    0
#
# [53423 rows x 8 columns]

# %%
modulo341_small
# Out:
#        CONGLOME  VIVIENDA  MIEPERHO  PERCEPHO  POBREZA      GASHOG2D  \
# 0          5009        12         2         2        3  25065.796875
# 1          5009        41         2         2        3  28650.019531
# 2          5009        98         6         4        3  38136.218750
# 3          5015         7         4         3        3  26812.154297
# 4          5015        19         4         3        3  63311.539062
# ...         ...       ...       ...       ...      ...           ...
# 34485     20305        31         1         1        3  12997.472656
# 34486     20305        52         1         1        3  10690.595703
# 34487     20305        73         1         1        3  11576.803711
# 34488     20305       116         4         1        3  23779.029297
# 34489     20305       137         4         2        3  16872.869141
#
#            INGHOG2D
# 0      37274.425781
# 1      41967.570312
# 2      42292.535156
# 3      37866.210938
# 4      91681.960938
# ...             ...
# 34485  14227.951172
# 34486  11442.000000
# 34487  12847.000000
# 34488  21009.353516
# 34489  19822.650391
#
# [34490 rows x 7 columns]

# %% [markdown]
# 4. El módulo vivienda incluye todos los hogares que entraron en el marco muestral, incluso aquellos que no participaron en la ENAHO por diversos motivos. Para eliminar estas viviendas, quedémonos con aquellas cuyo ``` RESULT``` sea igual a 1 ó 2. Almacena este resultado para después.

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %%
cond1 = modulo1_small['RESULT'] >= 1

cond2 = modulo1_small['RESULT'] <= 2


modulo1_smallr = modulo1_small[cond1 & cond2]

modulo1_smallr
# Out:
#        CONGLOME  VIVIENDA  HOGAR  RESULT NBI1 NBI2 NBI4 NBI5
# 0          5009        12     11       1    0    0    0    0
# 1          5009        41     11       1    0    0    0    0
# 4          5009        98     11       1    0    0    0    0
# 6          5015         7     11       1    0    0    0    0
# 7          5015        19     11       1    0    0    0    0
# ...         ...       ...    ...     ...  ...  ...  ...  ...
# 53417     20305        31     11       1    0    0    0    0
# 53418     20305        52     11       1    0    0    0    0
# 53419     20305        73     11       1    1    0    0    0
# 53421     20305       116     11       1    0    0    0    0
# 53422     20305       137     11       1    0    0    0    0
#
# [34490 rows x 8 columns]

# %% [markdown]
# 5. Queremos calcular una serie de variables (ó columnas nuevas):
# En sumaria:
# - Queremos el número de miembros dependientes del hogar . Estos son el número de personas que no perciben un ingreso ó la diferencia entre el total de miembros y el total de perceptores.
# - Queremos el ingreso mensual promedio por perceptor del hogar.
# - Queremos la diferencia  entre ingreso y gasto del hogar
#
#
# MIEPERHO: número de miembros del hogar.
# PERCEPHO: número de perceptores del hogar (que reciben un ingreso).
# POBREZA: Pobreza monetaria según la línea de pobreza.
# GASHOG2D: Gasto bruto anual del hogar.
# INGHOG2D: Ingreso anual neto total del hogar.

# %%
personas_dep = modulo341['MIEPERHO'] - modulo341['PERCEPHO']

modulo341['DEPENDIENTES'] = personas_dep

modulo341
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...  POBREZA  TIPOCUESTIONARIO  TIPOENTREVISTA  \
# 0             2         2  ...        3                 0               1
# 1             2         2  ...        3                 0               1
# 2             6         6  ...        3                 0               1
# 3             4         4  ...        3                 0               1
# 4             4         4  ...        3                 0               1
# ...         ...       ...  ...      ...               ...             ...
# 34485         1         1  ...        3                 2               1
# 34486         1         1  ...        3                 2               1
# 34487         1         1  ...        3                 2               1
# 34488         4         4  ...        3                 2               1
# 34489         4         4  ...        3                 2               1
#
#          FACTOR07  NCONGLOME  SUB_CONGLOME  LINEAV_RPL      LINEAV  POBREZAV  \
# 0      149.202744       7076             0         657  560.468506         4
# 1      149.202744       7076             0         657  553.731506         4
# 2      149.202744       7076             0         657  547.194031         3
# 3       70.492592       7089             0         657  556.025330         4
# 4       70.492592       7089             0         657  548.526917         4
# ...           ...        ...           ...         ...         ...       ...
# 34485  275.828552      15122             0         657  641.312134         4
# 34486  275.828552      15122             0         657  642.814026         4
# 34487  275.828552      15122             0         657  641.782898         4
# 34488  275.828552      15122             0         657  643.160034         3
# 34489  275.828552      15122             0         657  639.233521         3
#
#        DEPENDIENTES
# 0                 0
# 1                 0
# 2                 2
# 3                 1
# 4                 1
# ...             ...
# 34485             0
# 34486             0
# 34487             0
# 34488             3
# 34489             2
#
# [34490 rows x 180 columns]

# %%
ingreso_mensual = modulo341_small['INGHOG2D'] / modulo341_small['PERCEPHO'] / 12 

modulo341['INGRESOxMES'] = ingreso_mensual

modulo341
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...  TIPOCUESTIONARIO  TIPOENTREVISTA    FACTOR07  \
# 0             2         2  ...                 0               1  149.202744
# 1             2         2  ...                 0               1  149.202744
# 2             6         6  ...                 0               1  149.202744
# 3             4         4  ...                 0               1   70.492592
# 4             4         4  ...                 0               1   70.492592
# ...         ...       ...  ...               ...             ...         ...
# 34485         1         1  ...                 2               1  275.828552
# 34486         1         1  ...                 2               1  275.828552
# 34487         1         1  ...                 2               1  275.828552
# 34488         4         4  ...                 2               1  275.828552
# 34489         4         4  ...                 2               1  275.828552
#
#        NCONGLOME  SUB_CONGLOME  LINEAV_RPL      LINEAV  POBREZAV  \
# 0           7076             0         657  560.468506         4
# 1           7076             0         657  553.731506         4
# 2           7076             0         657  547.194031         3
# 3           7089             0         657  556.025330         4
# 4           7089             0         657  548.526917         4
# ...          ...           ...         ...         ...       ...
# 34485      15122             0         657  641.312134         4
# 34486      15122             0         657  642.814026         4
# 34487      15122             0         657  641.782898         4
# 34488      15122             0         657  643.160034         3
# 34489      15122             0         657  639.233521         3
#
#        DEPENDIENTES  INGRESOxMES
# 0                 0  1553.101074
# 1                 0  1748.648763
# 2                 2   881.094482
# 3                 1  1051.839193
# 4                 1  2546.721137
# ...             ...          ...
# 34485             0  1185.662598
# 34486             0   953.500000
# 34487             0  1070.583333
# 34488             3  1750.779460
# 34489             2   825.943766
#
# [34490 rows x 181 columns]

# %%
dif_ingreso_gas = (modulo341_small['INGHOG2D'] - modulo341_small['GASHOG2D'])

modulo341['INGRESO-GASTO'] = dif_ingreso_gas

modulo341
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...  TIPOENTREVISTA    FACTOR07  NCONGLOME  \
# 0             2         2  ...               1  149.202744       7076
# 1             2         2  ...               1  149.202744       7076
# 2             6         6  ...               1  149.202744       7076
# 3             4         4  ...               1   70.492592       7089
# 4             4         4  ...               1   70.492592       7089
# ...         ...       ...  ...             ...         ...        ...
# 34485         1         1  ...               1  275.828552      15122
# 34486         1         1  ...               1  275.828552      15122
# 34487         1         1  ...               1  275.828552      15122
# 34488         4         4  ...               1  275.828552      15122
# 34489         4         4  ...               1  275.828552      15122
#
#        SUB_CONGLOME  LINEAV_RPL      LINEAV  POBREZAV  DEPENDIENTES  \
# 0                 0         657  560.468506         4             0
# 1                 0         657  553.731506         4             0
# 2                 0         657  547.194031         3             2
# 3                 0         657  556.025330         4             1
# 4                 0         657  548.526917         4             1
# ...             ...         ...         ...       ...           ...
# 34485             0         657  641.312134         4             0
# 34486             0         657  642.814026         4             0
# 34487             0         657  641.782898         4             0
# 34488             0         657  643.160034         3             3
# 34489             0         657  639.233521         3             2
#
#        INGRESOxMES  INGRESO-GASTO
# 0      1553.101074   12208.628906
# 1      1748.648763   13317.550781
# 2       881.094482    4156.316406
# 3      1051.839193   11054.056641
# 4      2546.721137   28370.421875
# ...            ...            ...
# 34485  1185.662598    1230.478516
# 34486   953.500000     751.404297
# 34487  1070.583333    1270.196289
# 34488  1750.779460   -2769.675781
# 34489   825.943766    2949.781250
#
# [34490 rows x 182 columns]

# %% [markdown]
# 6. La variable de `pobreza`, en la sumaria, está codificada como integers 1, 2 y 3. Esto corresponde a:
# `1`: hogar pobre extremo
# `2`: hogar pobre no extremo
# `3`: hogar no  pobre
#
# En base a esta variable, crea dos variables más:
# 1. Una variable que tenga `'pobre extremo'`, `'pobre no extremo'` y `'no pobre'` en vez  de 1, 2, 3.
# 2. Una variable que tenga `'pobre'` y `'no pobre'` (ó que englobe a los hogares pobres y pobres no extremos).
