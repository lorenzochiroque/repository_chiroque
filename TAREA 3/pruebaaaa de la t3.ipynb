# %%
import pandas as pd

# %%
modulo1 = pd.read_csv('Enaho01-2020-100.csv')

# %%
modulo341 = pd.read_csv('Sumaria-2020.csv')

# %%
modulo342 = pd.read_csv('Sumaria-2020-12g.csv')

# %%
modulo1
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        56     11   10101        4        4
# 3      2020    1      5009        84     11   10101        4        4
# 4      2020    1      5009        98     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 53418  2020   12     20305        52     11  250301        7        4
# 53419  2020   12     20305        73     11  250301        7        4
# 53420  2020   12     20305        94     11  250301        7        4
# 53421  2020   12     20305       116     11  250301        7        4
# 53422  2020   12     20305       137     11  250301        7        4
#
#        PERIODO  TIPENC  ...    FACTOR07    FACTOR_P RECHAZO_RAZONES NCONGLOME  \
# 0            1       3  ...  149.202744  186.594396                      7076
# 1            1       3  ...  149.202744  186.594396                      7076
# 2            1       3  ...  149.202744  186.594396                      7076
# 3            1       3  ...  149.202744  186.594396                      7076
# 4            1       3  ...  149.202744  186.594396                      7076
# ...        ...     ...  ...         ...         ...             ...       ...
# 53418        2       1  ...  275.828552  379.820045                     15122
# 53419        2       1  ...  275.828552  379.820045                     15122
# 53420        2       1  ...  275.828552  379.820045                     15122
# 53421        2       1  ...  275.828552  379.820045                     15122
# 53422        2       1  ...  275.828552  379.820045                     15122
#
#       SUB_CONGLOME CODCCPP                     NOMCCPP   LONGITUD   LATITUD  \
# 0                0       1          CIUDAD CHACHAPOYAS -77.861290 -6.225835
# 1                0       1          CIUDAD CHACHAPOYAS -77.861290 -6.225835
# 2                0       1          CIUDAD CHACHAPOYAS -77.861290 -6.225835
# 3                0       1          CIUDAD CHACHAPOYAS -77.861290 -6.225835
# 4                0       1          CIUDAD CHACHAPOYAS -77.861290 -6.225835
# ...            ...     ...                         ...        ...       ...
# 53418            0       1  JUNTA VECINAL LAS PALMERAS -75.513435 -9.041584
# 53419            0       1      JUNTA VECINAL PALMERAS -75.513435 -9.041584
# 53420            0       1                    AGUAYTIA -75.513435 -9.041584
# 53421            0       1  JUNTA VECINAL LAS PALMERAS -75.513435 -9.041584
# 53422            0       1  JUNTA VECINAL LAS PALMERAS -75.513435 -9.041584
#
#       ALTITUD
# 0        2287
# 1        2287
# 2        2287
# 3        2287
# 4        2287
# ...       ...
# 53418     292
# 53419     292
# 53420     292
# 53421     292
# 53422     292
#
# [53423 rows x 331 columns]

# %%
modulo341
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...       LINEA  POBREZA  TIPOCUESTIONARIO  \
# 0             2         2  ...  303.520996        3                 0
# 1             2         2  ...  303.520996        3                 0
# 2             6         6  ...  303.520996        3                 0
# 3             4         4  ...  303.520996        3                 0
# 4             4         4  ...  303.520996        3                 0
# ...         ...       ...  ...         ...      ...               ...
# 34485         1         1  ...  335.352234        3                 2
# 34486         1         1  ...  335.352234        3                 2
# 34487         1         1  ...  335.352234        3                 2
# 34488         4         4  ...  335.352234        3                 2
# 34489         4         4  ...  335.352234        3                 2
#
#        TIPOENTREVISTA    FACTOR07  NCONGLOME  SUB_CONGLOME  LINEAV_RPL  \
# 0                   1  149.202744       7076             0         657
# 1                   1  149.202744       7076             0         657
# 2                   1  149.202744       7076             0         657
# 3                   1   70.492592       7089             0         657
# 4                   1   70.492592       7089             0         657
# ...               ...         ...        ...           ...         ...
# 34485               1  275.828552      15122             0         657
# 34486               1  275.828552      15122             0         657
# 34487               1  275.828552      15122             0         657
# 34488               1  275.828552      15122             0         657
# 34489               1  275.828552      15122             0         657
#
#            LINEAV  POBREZAV
# 0      560.468506         4
# 1      553.731506         4
# 2      547.194031         3
# 3      556.025330         4
# 4      548.526917         4
# ...           ...       ...
# 34485  641.312134         4
# 34486  642.814026         4
# 34487  641.782898         4
# 34488  643.160034         3
# 34489  639.233521         3
#
# [34490 rows x 179 columns]

# %%
modulo342
# Out:
#         A�O  MES  CONGLOME  VIVIENDA  HOGAR  UBIGEO  DOMINIO  ESTRATO  \
# 0      2020    1      5009        12     11   10101        4        4
# 1      2020    1      5009        41     11   10101        4        4
# 2      2020    1      5009        98     11   10101        4        4
# 3      2020    1      5015         7     11   10101        4        4
# 4      2020    1      5015        19     11   10101        4        4
# ...     ...  ...       ...       ...    ...     ...      ...      ...
# 34485  2020   12     20305        31     11  250301        7        4
# 34486  2020   12     20305        52     11  250301        7        4
# 34487  2020   12     20305        73     11  250301        7        4
# 34488  2020   12     20305       116     11  250301        7        4
# 34489  2020   12     20305       137     11  250301        7        4
#
#        MIEPERHO  TOTMIEHO  ...       LINEA  POBREZA  TIPOCUESTIONARIO  \
# 0             2         2  ...  303.520996        3                 0
# 1             2         2  ...  303.520996        3                 0
# 2             6         6  ...  303.520996        3                 0
# 3             4         4  ...  303.520996        3                 0
# 4             4         4  ...  303.520996        3                 0
# ...         ...       ...  ...         ...      ...               ...
# 34485         1         1  ...  335.352234        3                 2
# 34486         1         1  ...  335.352234        3                 2
# 34487         1         1  ...  335.352234        3                 2
# 34488         4         4  ...  335.352234        3                 2
# 34489         4         4  ...  335.352234        3                 2
#
#        TIPOENTREVISTA    FACTOR07  NCONGLOME  SUB_CONGLOME  LINEAV_RPL  \
# 0                   1  149.202744       7076             0         657
# 1                   1  149.202744       7076             0         657
# 2                   1  149.202744       7076             0         657
# 3                   1   70.492592       7089             0         657
# 4                   1   70.492592       7089             0         657
# ...               ...         ...        ...           ...         ...
# 34485               1  275.828552      15122             0         657
# 34486               1  275.828552      15122             0         657
# 34487               1  275.828552      15122             0         657
# 34488               1  275.828552      15122             0         657
# 34489               1  275.828552      15122             0         657
#
#            LINEAV  POBREZAV
# 0      560.468506         4
# 1      553.731506         4
# 2      547.194031         3
# 3      556.025330         4
# 4      548.526917         4
# ...           ...       ...
# 34485  641.312134         4
# 34486  642.814026         4
# 34487  641.782898         4
# 34488  643.160034         3
# 34489  639.233521         3
#
# [34490 rows x 252 columns]

# %% [markdown]
# 2. - ¿Cuáles son las dimensiones de la sumaria? (o el número de filas y columnas).
#    - ¿Cuáles son las dimensiones del módulo de vivienda? (o el número de filas y columnas).

# %%
modulo1.shape
# Out:
# (53423, 331)

# %%
modulo341.shape
# Out:
# (34490, 179)

# %%
modulo342.shape
# Out:
# (34490, 252)

# %% [markdown]
# 3. En esta oportunidad no necesitaremos todas las variables de la ENAHO para hacer esta tarea.
# - Quedémonos con las variables ``` CONGLOME VIVIENDA HOGAR MIEPERHO PERCEPHO POBREZA GASHOG2D INGHOG2D ``` de la sumaria.
# - Quedémonos con las variables ``` CONGLOME VIVIENDA HOGAR RESULT NBI1 NBI2 NBI3 NBI4 NBI5 ``` del módulo de vivienda.
#
#
#  Nota: cada una de las variables es:
# - MIEPERHO: número de miembros del hogar.
# - PERCEPHO: número de perceptores del hogar (que reciben un ingreso).
# - POBREZA: Pobreza monetaria según la línea de pobreza.
# - GASHOG2D: Gasto bruto anual del hogar.
# - INGHOG2D: Ingreso anual neto total del hogar.
#
# Necesidades básicas:
# - NBI1: vivienda inadecuada.
# - NBI2: hacinamiento
# - NBI3: vivienda sin servicios higiénicos
# - NBI4: hogares con  niños que no asisten a la escuela.
# - NBI5: hogares con alta dependencia económica
#
# CONGLOME, VIVIENDA y HOGAR son los identificadores únicos a nivel de hogar (como un key id).

# %%
modulo1.columns
# Out:
# Index(['A�O', 'MES', 'CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO', 'DOMINIO',
#        'ESTRATO', 'PERIODO', 'TIPENC',
#        ...
#        'FACTOR07', 'FACTOR_P', 'RECHAZO_RAZONES', 'NCONGLOME', 'SUB_CONGLOME',
#        'CODCCPP', 'NOMCCPP', 'LONGITUD', 'LATITUD', 'ALTITUD'],
#       dtype='object', length=331)

# %%
necessmodulo1 = ['CONGLOME', 'VIVIENDA', 'HOGAR', 'RESULT', 'NBI1', 'NBI2', 'NBI4', 'NBI5']

# %%
necessmodulo341 = ['CONGLOME', 'VIVIENDA', 'MIEPERHO', 'PERCEPHO', 'POBREZA', 'GASHOG2D', 'INGHOG2D']

# %%
necessmodulo342 = ['CONGLOME', 'VIVIENDA', 'MIEPERHO', 'PERCEPHO', 'POBREZA', 'GASHOG2D', 'INGHOG2D']

# %%
modulo1[necessmodulo1]
# Out:
#        CONGLOME  VIVIENDA  HOGAR  RESULT NBI1 NBI2 NBI4 NBI5
# 0          5009        12     11       1    0    0    0    0
# 1          5009        41     11       1    0    0    0    0
# 2          5009        56     11       7
# 3          5009        84     11       7
# 4          5009        98     11       1    0    0    0    0
# ...         ...       ...    ...     ...  ...  ...  ...  ...
# 53418     20305        52     11       1    0    0    0    0
# 53419     20305        73     11       1    1    0    0    0
# 53420     20305        94     11       7
# 53421     20305       116     11       1    0    0    0    0
# 53422     20305       137     11       1    0    0    0    0
#
# [53423 rows x 8 columns]

# %%
modulo341_small = modulo341[necessmodulo341]

# %%
modulo342_small = modulo342[necessmodulo342]

# %%
modulo1_small
# Out:
# [['CONGLOME', 'VIVIENDA', 'HOGAR', 'RESULT', 'NBT1', 'NBT2', 'NBT4', 'NBT5']]

# %%
modulo341_small
# Out:
#        CONGLOME  VIVIENDA  MIEPERHO  PERCEPHO  POBREZA      GASHOG2D  \
# 0          5009        12         2         2        3  25065.796875
# 1          5009        41         2         2        3  28650.019531
# 2          5009        98         6         4        3  38136.218750
# 3          5015         7         4         3        3  26812.154297
# 4          5015        19         4         3        3  63311.539062
# ...         ...       ...       ...       ...      ...           ...
# 34485     20305        31         1         1        3  12997.472656
# 34486     20305        52         1         1        3  10690.595703
# 34487     20305        73         1         1        3  11576.803711
# 34488     20305       116         4         1        3  23779.029297
# 34489     20305       137         4         2        3  16872.869141
#
#            INGHOG2D
# 0      37274.425781
# 1      41967.570312
# 2      42292.535156
# 3      37866.210938
# 4      91681.960938
# ...             ...
# 34485  14227.951172
# 34486  11442.000000
# 34487  12847.000000
# 34488  21009.353516
# 34489  19822.650391
#
# [34490 rows x 7 columns]

# %%
modulo342_small
# Out:
#        CONGLOME  VIVIENDA  MIEPERHO  PERCEPHO  POBREZA      GASHOG2D  \
# 0          5009        12         2         2        3  25065.796875
# 1          5009        41         2         2        3  28650.019531
# 2          5009        98         6         4        3  38136.218750
# 3          5015         7         4         3        3  26812.154297
# 4          5015        19         4         3        3  63311.539062
# ...         ...       ...       ...       ...      ...           ...
# 34485     20305        31         1         1        3  12997.472656
# 34486     20305        52         1         1        3  10690.595703
# 34487     20305        73         1         1        3  11576.803711
# 34488     20305       116         4         1        3  23779.029297
# 34489     20305       137         4         2        3  16872.869141
#
#            INGHOG2D
# 0      37274.425781
# 1      41967.570312
# 2      42292.535156
# 3      37866.210938
# 4      91681.960938
# ...             ...
# 34485  14227.951172
# 34486  11442.000000
# 34487  12847.000000
# 34488  21009.353516
# 34489  19822.650391
#
# [34490 rows x 7 columns]
